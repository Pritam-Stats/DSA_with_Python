# %% [markdown]
# ## Next Greater Element on a Circular Array
#
# - Main Funda is the Circular array

# %%
def nextGreater(nums: list) -> list:
    n = len(nums)
    stack = []
    ans = []
# Out:
# 2
